# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhavbaviskar21-maker/DSBDA/blob/main/Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import  pandas as pd
import numpy as np

df = pd.read_csv("/content/HR DATA.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
grouped_stat = df.groupby("Attrition")[["Age","MonthlyIncome"]].agg(["mean","median","min","max","std"])

print(grouped_stat)
# Out:
#                  Age                         MonthlyIncome                \
#                 mean median min max      std          mean  median   min
# Attrition
# No         37.561233   36.0  18  60  8.88836   6832.739659  5204.0  1051
# Yes        33.607595   32.0  18  58  9.68935   4787.092827  3202.0  1009
#
#
#              max          std
# Attrition
# No         19999  4818.208001
# Yes        19859  3640.210367

# %%
income_yes = df[df["Attrition"] == "Yes"]["MonthlyIncome"].tolist()
income_no = df[df["Attrition"] == "No"]["MonthlyIncome"].tolist()

print("Income List for Attrition = Yes:", income_yes[:5])
print("Income List for Attrition = No:", income_no[:5])
# Out:
# Income List for Attrition = Yes: [5993, 2090, 2028, 3407, 2960]
# Income List for Attrition = No: [5130, 2909, 3468, 3068, 2670]

# %%
iris = pd.read_csv("Iris.csv")
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
print("Statitistics For Iris-setos")
print(iris[iris["Species"]=="Iris-setosa"].describe())

print("\n Statistics for Iris-versicolor")
print(iris[iris["Species"]=="Iris-versicolor"].describe())

print("\n Statistics for Iris-virginica")
print(iris[iris["Species"]=="Iris-virginica"].describe())
# Out:
# Statitistics For Iris-setos
#              Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  50.00000       50.00000     50.000000      50.000000      50.00000
# mean   25.50000        5.00600      3.418000       1.464000       0.24400
# std    14.57738        0.35249      0.381024       0.173511       0.10721
# min     1.00000        4.30000      2.300000       1.000000       0.10000
# 25%    13.25000        4.80000      3.125000       1.400000       0.20000
# 50%    25.50000        5.00000      3.400000       1.500000       0.20000
# 75%    37.75000        5.20000      3.675000       1.575000       0.30000
# max    50.00000        5.80000      4.400000       1.900000       0.60000
#
#  Statistics for Iris-versicolor
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000      50.000000     50.000000      50.000000     50.000000
# mean    75.50000       5.936000      2.770000       4.260000      1.326000
# ...

# %%
for Species in iris["Species"].unique():
  print("\nSpecies : ",Species)
  subset = iris[iris["Species"] == Species]
  print("Mean:\n", subset.mean(numeric_only=True))
  print("Median:\n", subset.median(numeric_only=True))
  print("Standard Deviation:\n", subset.std(numeric_only=True))
# Out:
# Species :  Iris-setosa
# Mean:
#  Id               25.500
# SepalLengthCm     5.006
# SepalWidthCm      3.418
# PetalLengthCm     1.464
# PetalWidthCm      0.244
# dtype: float64
# Median:
#  Id               25.5
# SepalLengthCm     5.0
# SepalWidthCm      3.4
# PetalLengthCm     1.5
# PetalWidthCm      0.2
# dtype: float64
# Standard Deviation:
#  Id               14.577380
# SepalLengthCm     0.352490
# SepalWidthCm      0.381024
# PetalLengthCm     0.173511
# PetalWidthCm      0.107210
# dtype: float64
#
# Species :  Iris-versicolor
# Mean:
#  Id               75.500
# SepalLengthCm     5.936
# SepalWidthCm      2.770
# PetalLengthCm     4.260
# PetalWidthCm      1.326
# dtype: float64
# Median:
#  Id               75.50
# SepalLengthCm     5.90
# SepalWidthCm      2.80
# PetalLengthCm     4.35
# PetalWidthCm      1.30
# dtype: float64
# Standard Deviation:
#  Id               14.577380
# SepalLengthCm     0.516171
# SepalWidthCm      0.313798
# PetalLengthCm     0.469911
# ...
