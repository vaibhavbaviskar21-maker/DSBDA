# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhavbaviskar21-maker/DSBDA/blob/main/dsbda_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

titanic_df = sns.load_dataset('titanic')

print("First 5 rows of the Titanic dataset:")
display(titanic_df.head())

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='sex', y='age', hue='survived', data=titanic_df, palette='viridis')
plt.title('Age Distribution by Gender and Survival Status on the Titanic')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.xticks(ticks=[0, 1], labels=['Male', 'Female'])
plt.legend(title='Survived', loc='upper right', labels=['No', 'Yes'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
