# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhavbaviskar21-maker/DSBDA/blob/main/dsbda4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)

data_features = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target_values = raw_df.values[1::2, 2]

feature_names = [
    'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT'
]

from sklearn.utils import Bunch
boston = Bunch(
    data=data_features,
    target=target_values,
    feature_names=feature_names,
    DESCR="Boston Housing Dataset (fetched from original source due to removal from scikit-learn)"
)
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_1866/1178861713.py:6: SyntaxWarning: invalid escape sequence '\s'
#   raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)

# %%
data = pd.DataFrame(boston.data, columns=boston.feature_names)
display(data.head())
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
data['PRICE'] = boston.target
display(data.head())
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  PRICE
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
print(data.isnull().sum())
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# PRICE      0
# dtype: int64

# %%
x = data.drop(['PRICE'], axis=1)
y = data['PRICE']
print("Shape of X:", x.shape)
print("Shape of Y:", y.shape)
# Out:
# Shape of X: (506, 13)
# Shape of Y: (506,)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=0)
print("Shape of xtrain:", xtrain.shape)
print("Shape of xtest:", xtest.shape)
print("Shape of ytrain:", ytrain.shape)
print("Shape of ytest:", ytest.shape)
# Out:
# Shape of xtrain: (404, 13)
# Shape of xtest: (102, 13)
# Shape of ytrain: (404,)
# Shape of ytest: (102,)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
model = lm.fit(xtrain, ytrain)

# %%
ytrain_pred = lm.predict(xtrain)
ytest_pred = lm.predict(xtest)

# %%
df_train_preds = pd.DataFrame({'Actual': ytrain, 'Predicted': ytrain_pred})
df_test_preds = pd.DataFrame({'Actual': ytest, 'Predicted': ytest_pred})

print("\n--- Training Data Predictions ---")
display(df_train_preds.head())
print("\n--- Test Data Predictions ---")
display(df_test_preds.head())
# Out:
# --- Training Data Predictions ---
#      Actual  Predicted
# 220    26.7  32.556927
# 71     21.7  21.927095
# 240    22.0  27.543826
# 6      22.9  23.603188
# 417    10.4   6.571910
# --- Test Data Predictions ---
#      Actual  Predicted
# 329    22.6  24.889638
# 371    50.0  23.721411
# 219    23.0  29.364999
# 403     8.3  12.122386
# 78     21.2  21.443823

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse_test = mean_squared_error(ytest, ytest_pred)
r2_test = r2_score(ytest, ytest_pred)

mse_train = mean_squared_error(ytrain, ytrain_pred)
r2_train = r2_score(ytrain, ytrain_pred)

print(f"Mean Squared Error (Test): {mse_test:.4f}")
print(f"R-squared (Test): {r2_test:.4f}")
print(f"Mean Squared Error (Train): {mse_train:.4f}")
print(f"R-squared (Train): {r2_train:.4f}")
# Out:
# Mean Squared Error (Test): 33.4490
# R-squared (Test): 0.5892
# Mean Squared Error (Train): 19.3265
# R-squared (Train): 0.7730
