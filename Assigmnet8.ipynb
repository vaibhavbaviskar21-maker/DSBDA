# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhavbaviskar21-maker/DSBDA/blob/main/Assigmnet8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

dataset = sns.load_dataset('titanic')

sns.histplot(data=dataset, x='fare', kde=False, bins=10)
plt.title('Distribution of Ticket Prices (Fare)')
plt.xlabel('Fare')
plt.ylabel('Number of Passengers')
plt.show()

# %%
sns.swarmplot(x='sex', y='age', data=dataset, hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.violinplot(x='sex', y='age', data=dataset)
plt.title('Age Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.show()

# %%
sns.countplot(x='sex', hue='survived', data=dataset)
plt.title('Survival Count by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()

# %%
sns.jointplot(x='age', y='fare', data=dataset, kind='scatter')
plt.title('Survival Count by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()

# %%
sns.swarmplot(x='pclass', y='age', hue='survived', data=dataset)
plt.title('Survival Count by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 15.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.histplot(data=dataset, x='fare', kde=True, bins=10)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>
