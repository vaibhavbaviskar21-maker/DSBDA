# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhavbaviskar21-maker/DSBDA/blob/main/dsbda7b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
form sklearn.feature_extraction.text
import TfidVectorizer

documentA="Jupiter is the largest Planet"
documentB-"Mars is the fourth planet from the sun"

bagOfWordsA= documentA.split(' ')
bagOfWordsB= documentB.split(' ')

uniqueWord = set(bagOfWordsA).union(set(bagOfWordsB))

numOfWordsA = dict.fromkeys(uniqueWord,0)
for word in bagOfWordsA:
    numOfWordsA[word]+=1
    numOfWordsB = dict.fromkeys(uniqueWord,0)
    for word in bagOfWordsB:
      numOfWordsB[word]+=1

def computerTF(wordDict,bagOfWords):
  tfDict =()
  bagOfWordsCount= len(bagOfWords)
  for word,count in wordDict.items():
    tfDict[word]=count/float(bagOfWordsCount)
  return tfDict

  tfA = computerTF(numOfWordsA,bagOfWordsA)
  tfB = computerTF(numOfWordsB,bagOfWordsB)

  import math
  def computerIDF(documents):
    idfDict = dict.fromkeys(documents[0].keys(),0)
    for document in documents:
      for word,val in document.items():
        if val>0:
          idfDict[word]+=1
  for word,val in document.items():
    idfDict[word]=math.log(N/float(val))
  return idfDict
  idfs = computerIDF([numOfWordsA,numOfWordsB])
  idfs

  def computeTFIDF(tfBagOfWords,idfs):
    tfidf = {}
    for word,val in tfBagOfWord.items():
      tfidf[word]=val*idfs[word]
  return tfidf

  tfidfA=computeTFID(tfBagOfWords,idfs):
  tfidf = {}
  for word,al
